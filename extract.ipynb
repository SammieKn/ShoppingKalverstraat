# %%
import requests
import pandas as pd
import time

# %%
def get_pedestrian_data(params, key):
    """
    Fetch pedestrian data from the Amsterdam Datapunt API with dynamic query parameters.

    Args:
    params (dict): Dictionary of query parameters to filter the data.

    Returns:
    DataFrame: Pandas DataFrame containing the pedestrian data.
    """
    base_url = "https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/"
    items = []
    first = True
    while base_url:
        if first:
            response = requests.get(base_url, params=params, headers=key)
            first = False
        else:
            response = requests.get(base_url, headers=key)

        if response.status_code != 200:
            # Load data into DataFrame
            raise Exception(f"Failed to fetch data: {response.status_code} - {response.text}")
        data = response.json()
        items.extend(data['_embedded']['passanten'])
        next_link = data['_links'].get('next', {}).get('href')
        base_url = next_link
    
    return items

# %%
params = {
    "sensor": "CMSA-GAKH-01",
    "datumUur[gte]": "2023-01-01",
    "datumUur[lt]": "2024-01-01",
}

api_file = "apikey.txt"

with open(api_file, 'r') as f:
    apikey = {
        "X-Api-Key": f.read()
    }

start_time = time.time()
response = get_pedestrian_data(params, apikey)
end_time = time.time()

print(f'The data has been pulled succesfully, request took: {end_time - start_time} seconds')
# Out:
# The data has been pulled succesfully, request took: 273.284786939621 seconds

# %%
response
# Out:
# [{'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/54/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 54}},
#   'id': 54,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-05T12:00:00',
#   'aantalPassanten': 1150,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/434/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 434}},
#   'id': 434,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-05-28T11:00:00',
#   'aantalPassanten': 2699,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/445/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 445}},
#   'id': 445,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-05-30T04:00:00',
#   'aantalPassanten': 75,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/953/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 953}},
#   'id': 953,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-10-29T20:00:00',
#   'aantalPassanten': 722,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/1302/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 1302}},
#   'id': 1302,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-02-01T18:00:00',
#   'aantalPassanten': 2188,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/1396/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 1396}},
#   'id': 1396,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-01-10T08:00:00',
#   'aantalPassanten': 176,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/1423/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 1423}},
#   'id': 1423,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-12T05:00:00',
#   'aantalPassanten': 119,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/1488/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 1488}},
#   'id': 1488,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-09T22:00:00',
#   'aantalPassanten': 513,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/1510/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 1510}},
#   'id': 1510,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-04-03T23:00:00',
#   'aantalPassanten': 275,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/1552/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 1552}},
#   'id': 1552,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-05-20T20:00:00',
#   'aantalPassanten': 1856,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/1847/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 1847}},
#   'id': 1847,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-12-04T20:00:00',
#   'aantalPassanten': 794,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/1856/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 1856}},
#   'id': 1856,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-02-23T19:00:00',
#   'aantalPassanten': 2643,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/2129/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 2129}},
#   'id': 2129,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-03-14T11:00:00',
#   'aantalPassanten': 1190,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/2312/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 2312}},
#   'id': 2312,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-04-28T04:00:00',
#   'aantalPassanten': 300,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/2416/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 2416}},
#   'id': 2416,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-04-24T13:00:00',
#   'aantalPassanten': 4457,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/2443/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 2443}},
#   'id': 2443,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-12-06T06:00:00',
#   'aantalPassanten': 75,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/2516/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 2516}},
#   'id': 2516,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-05-25T14:00:00',
#   'aantalPassanten': 4445,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/2695/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 2695}},
#   'id': 2695,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-01-16T00:00:00',
#   'aantalPassanten': 168,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/2705/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 2705}},
#   'id': 2705,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-01-06T06:00:00',
#   'aantalPassanten': 60,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/2878/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 2878}},
#   'id': 2878,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-30T20:00:00',
#   'aantalPassanten': 1131,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/2909/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 2909}},
#   'id': 2909,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-08-21T10:00:00',
#   'aantalPassanten': 1129,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/3154/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 3154}},
#   'id': 3154,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-04-12T09:00:00',
#   'aantalPassanten': 474,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/3173/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 3173}},
#   'id': 3173,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-05-13T06:00:00',
#   'aantalPassanten': 86,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/3237/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 3237}},
#   'id': 3237,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-31T20:00:00',
#   'aantalPassanten': 1220,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/3338/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 3338}},
#   'id': 3338,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-02T02:00:00',
#   'aantalPassanten': 233,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/3361/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 3361}},
#   'id': 3361,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-08-09T17:00:00',
#   'aantalPassanten': 5898,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/3634/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 3634}},
#   'id': 3634,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-03-30T12:00:00',
#   'aantalPassanten': 2656,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/3662/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 3662}},
#   'id': 3662,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-09-12T06:00:00',
#   'aantalPassanten': 67,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/3926/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 3926}},
#   'id': 3926,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-06-19T12:00:00',
#   'aantalPassanten': 3193,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/3946/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 3946}},
#   'id': 3946,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-05-24T10:00:00',
#   'aantalPassanten': 1037,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/4082/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 4082}},
#   'id': 4082,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-05-24T20:00:00',
#   'aantalPassanten': 1115,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/4197/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 4197}},
#   'id': 4197,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-06-15T18:00:00',
#   'aantalPassanten': 4115,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/4437/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 4437}},
#   'id': 4437,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-03-01T14:00:00',
#   'aantalPassanten': 5066,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/4485/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 4485}},
#   'id': 4485,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-10-03T00:00:00',
#   'aantalPassanten': 146,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/4755/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 4755}},
#   'id': 4755,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-03-16T07:00:00',
#   'aantalPassanten': 85,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/4784/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 4784}},
#   'id': 4784,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-05-26T21:00:00',
#   'aantalPassanten': 1251,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/4897/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 4897}},
#   'id': 4897,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-01T18:00:00',
#   'aantalPassanten': 5725,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/5086/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 5086}},
#   'id': 5086,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-06-03T20:00:00',
#   'aantalPassanten': 2075,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/5183/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 5183}},
#   'id': 5183,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-04-20T04:00:00',
#   'aantalPassanten': 213,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/5293/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 5293}},
#   'id': 5293,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-03-30T21:00:00',
#   'aantalPassanten': 982,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/5356/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 5356}},
#   'id': 5356,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-04-30T02:00:00',
#   'aantalPassanten': 204,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/5389/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 5389}},
#   'id': 5389,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-05-20T03:00:00',
#   'aantalPassanten': 146,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/5428/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 5428}},
#   'id': 5428,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-11-18T07:00:00',
#   'aantalPassanten': 97,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/5508/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 5508}},
#   'id': 5508,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-09-24T13:00:00',
#   'aantalPassanten': 6127,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/5636/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 5636}},
#   'id': 5636,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-12-31T00:00:00',
#   'aantalPassanten': 492,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/5645/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 5645}},
#   'id': 5645,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-02-07T03:00:00',
#   'aantalPassanten': 78,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/5692/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 5692}},
#   'id': 5692,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-01-02T03:00:00',
#   'aantalPassanten': 79,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/5840/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 5840}},
#   'id': 5840,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-08-16T07:00:00',
#   'aantalPassanten': 84,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/5945/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 5945}},
#   'id': 5945,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-03-02T22:00:00',
#   'aantalPassanten': 481,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/6153/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 6153}},
#   'id': 6153,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-03-27T00:00:00',
#   'aantalPassanten': 167,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/6207/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 6207}},
#   'id': 6207,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-04T05:00:00',
#   'aantalPassanten': 67,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/6288/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 6288}},
#   'id': 6288,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-09-06T02:00:00',
#   'aantalPassanten': 110,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/6294/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 6294}},
#   'id': 6294,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-05-24T00:00:00',
#   'aantalPassanten': 132,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/6326/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 6326}},
#   'id': 6326,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-06-21T00:00:00',
#   'aantalPassanten': 172,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/6383/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 6383}},
#   'id': 6383,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-02-15T12:00:00',
#   'aantalPassanten': 2664,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/6439/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 6439}},
#   'id': 6439,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-12-31T12:00:00',
#   'aantalPassanten': 3882,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/6535/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 6535}},
#   'id': 6535,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-19T20:00:00',
#   'aantalPassanten': 1608,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/6718/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 6718}},
#   'id': 6718,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-06-08T02:00:00',
#   'aantalPassanten': 111,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/7108/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 7108}},
#   'id': 7108,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-12-18T21:00:00',
#   'aantalPassanten': 599,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/7143/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 7143}},
#   'id': 7143,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-12-24T07:00:00',
#   'aantalPassanten': 85,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/7253/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 7253}},
#   'id': 7253,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-02-02T21:00:00',
#   'aantalPassanten': 932,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/7330/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 7330}},
#   'id': 7330,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-04-01T00:00:00',
#   'aantalPassanten': 330,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/7479/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 7479}},
#   'id': 7479,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-06-24T04:00:00',
#   'aantalPassanten': 218,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/7670/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 7670}},
#   'id': 7670,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-04-01T18:00:00',
#   'aantalPassanten': 4301,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/7735/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 7735}},
#   'id': 7735,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-03-22T12:00:00',
#   'aantalPassanten': 2179,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/7948/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 7948}},
#   'id': 7948,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-04T16:00:00',
#   'aantalPassanten': 6001,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/7953/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 7953}},
#   'id': 7953,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-12-19T23:00:00',
#   'aantalPassanten': 262,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8035/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8035}},
#   'id': 8035,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-01-18T04:00:00',
#   'aantalPassanten': 76,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8040/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8040}},
#   'id': 8040,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-03-01T02:00:00',
#   'aantalPassanten': 88,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8103/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8103}},
#   'id': 8103,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-11-22T02:00:00',
#   'aantalPassanten': 100,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8106/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8106}},
#   'id': 8106,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-10-18T18:00:00',
#   'aantalPassanten': 3856,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8172/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8172}},
#   'id': 8172,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-12-15T19:00:00',
#   'aantalPassanten': 2899,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8256/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8256}},
#   'id': 8256,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-04-23T17:00:00',
#   'aantalPassanten': 4031,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8367/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8367}},
#   'id': 8367,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-08-24T13:00:00',
#   'aantalPassanten': 4362,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8390/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8390}},
#   'id': 8390,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-09-13T13:00:00',
#   'aantalPassanten': 2852,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8422/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8422}},
#   'id': 8422,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-10-22T04:00:00',
#   'aantalPassanten': 239,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8497/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8497}},
#   'id': 8497,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-05-30T12:00:00',
#   'aantalPassanten': 3618,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8756/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8756}},
#   'id': 8756,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-08-26T02:00:00',
#   'aantalPassanten': 209,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8817/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8817}},
#   'id': 8817,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-10-16T03:00:00',
#   'aantalPassanten': 86,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8880/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8880}},
#   'id': 8880,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-04-08T08:00:00',
#   'aantalPassanten': 138,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8937/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8937}},
#   'id': 8937,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-12-07T11:00:00',
#   'aantalPassanten': 2095,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/8943/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 8943}},
#   'id': 8943,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-07T14:00:00',
#   'aantalPassanten': 4695,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/9319/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 9319}},
#   'id': 9319,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-08-31T15:00:00',
#   'aantalPassanten': 6138,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/9554/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 9554}},
#   'id': 9554,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-04-08T07:00:00',
#   'aantalPassanten': 102,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/9732/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 9732}},
#   'id': 9732,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-10-24T20:00:00',
#   'aantalPassanten': 876,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/9752/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 9752}},
#   'id': 9752,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-08-17T14:00:00',
#   'aantalPassanten': 5767,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/10001/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 10001}},
#   'id': 10001,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-08T07:00:00',
#   'aantalPassanten': 107,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/10023/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 10023}},
#   'id': 10023,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-10-22T18:00:00',
#   'aantalPassanten': 4537,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/10132/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 10132}},
#   'id': 10132,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-06-20T05:00:00',
#   'aantalPassanten': 65,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
# ...
#   'datumUur': '2023-01-15T02:00:00',
#   'aantalPassanten': 253,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/114496/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 114496}},
#   'id': 114496,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-10-08T06:00:00',
#   'aantalPassanten': 108,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/114509/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 114509}},
#   'id': 114509,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-01-14T14:00:00',
#   'aantalPassanten': 3354,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/114543/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 114543}},
#   'id': 114543,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-10-18T14:00:00',
#   'aantalPassanten': 4626,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/114578/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 114578}},
#   'id': 114578,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-01-01T12:00:00',
#   'aantalPassanten': 2132,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/114666/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 114666}},
#   'id': 114666,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-08-28T16:00:00',
#   'aantalPassanten': 4964,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/114886/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 114886}},
#   'id': 114886,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-12-26T21:00:00',
#   'aantalPassanten': 975,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/115305/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 115305}},
#   'id': 115305,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-11-09T23:00:00',
#   'aantalPassanten': 292,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/115348/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 115348}},
#   'id': 115348,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-10-05T16:00:00',
#   'aantalPassanten': 4628,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/115510/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 115510}},
#   'id': 115510,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-26T14:00:00',
#   'aantalPassanten': 6645,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/115518/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 115518}},
#   'id': 115518,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-11-11T00:00:00',
#   'aantalPassanten': 361,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/115607/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 115607}},
#   'id': 115607,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-06-29T20:00:00',
#   'aantalPassanten': 2793,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/115696/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 115696}},
#   'id': 115696,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-06-21T09:00:00',
#   'aantalPassanten': 458,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/115717/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 115717}},
#   'id': 115717,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-11-03T08:00:00',
#   'aantalPassanten': 164,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/115775/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 115775}},
#   'id': 115775,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-09-08T01:00:00',
#   'aantalPassanten': 125,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/115819/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 115819}},
#   'id': 115819,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-10-08T02:00:00',
#   'aantalPassanten': 174,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/115854/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 115854}},
#   'id': 115854,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-04-21T07:00:00',
#   'aantalPassanten': 63,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/116162/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 116162}},
#   'id': 116162,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-09-21T13:00:00',
#   'aantalPassanten': 3036,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/116192/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 116192}},
#   'id': 116192,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-04-18T06:00:00',
#   'aantalPassanten': 65,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/116536/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 116536}},
#   'id': 116536,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-11-22T00:00:00',
#   'aantalPassanten': 144,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/116558/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 116558}},
#   'id': 116558,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-11-12T17:00:00',
#   'aantalPassanten': 6017,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/116582/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 116582}},
#   'id': 116582,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-06-28T02:00:00',
#   'aantalPassanten': 107,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/116584/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 116584}},
#   'id': 116584,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-09-15T20:00:00',
#   'aantalPassanten': 1314,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/116626/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 116626}},
#   'id': 116626,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-12-01T15:00:00',
#   'aantalPassanten': 4995,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/116676/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 116676}},
#   'id': 116676,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-12-13T03:00:00',
#   'aantalPassanten': 87,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/117038/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 117038}},
#   'id': 117038,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-01-14T19:00:00',
#   'aantalPassanten': 2011,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/117047/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 117047}},
#   'id': 117047,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-05-03T08:00:00',
#   'aantalPassanten': 188,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/117223/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 117223}},
#   'id': 117223,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-07-09T20:00:00',
#   'aantalPassanten': 1198,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/117354/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 117354}},
#   'id': 117354,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-06-24T03:00:00',
#   'aantalPassanten': 247,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  {'_links': {'schema': 'https://schemas.data.amsterdam.nl/datasets/crowdmonitor/dataset#passanten',
#    'self': {'href': 'https://api.data.amsterdam.nl/v1/crowdmonitor/passanten/117502/',
#     'title': 'Kalverstraat t.h.v. 1',
#     'id': 117502}},
#   'id': 117502,
#   'sensor': 'CMSA-GAKH-01',
#   'periode': 'uur',
#   'naamLocatie': 'Kalverstraat t.h.v. 1',
#   'datumUur': '2023-09-23T13:00:00',
#   'aantalPassanten': 5533,
#   'gebied': 'Winkelgebied centrum',
#   'geometrie': {'type': 'Point',
#    'coordinates': [121281.37087987993, 487310.4878591449]}},
#  ...]

# %%
df = pd.DataFrame(response)

# %%
df
# Out:
#                                                   _links       id  \
# 0      {'schema': 'https://schemas.data.amsterdam.nl/...       54
# 1      {'schema': 'https://schemas.data.amsterdam.nl/...      434
# 2      {'schema': 'https://schemas.data.amsterdam.nl/...      445
# 3      {'schema': 'https://schemas.data.amsterdam.nl/...      953
# 4      {'schema': 'https://schemas.data.amsterdam.nl/...     1302
# ...                                                  ...      ...
# 12765  {'schema': 'https://schemas.data.amsterdam.nl/...  1454562
# 12766  {'schema': 'https://schemas.data.amsterdam.nl/...  1454638
# 12767  {'schema': 'https://schemas.data.amsterdam.nl/...  1454653
# 12768  {'schema': 'https://schemas.data.amsterdam.nl/...  1454686
# 12769  {'schema': 'https://schemas.data.amsterdam.nl/...  1454791
#
#              sensor periode            naamLocatie             datumUur  \
# 0      CMSA-GAKH-01     uur  Kalverstraat t.h.v. 1  2023-07-05T12:00:00
# 1      CMSA-GAKH-01     uur  Kalverstraat t.h.v. 1  2023-05-28T11:00:00
# 2      CMSA-GAKH-01     uur  Kalverstraat t.h.v. 1  2023-05-30T04:00:00
# 3      CMSA-GAKH-01     uur  Kalverstraat t.h.v. 1  2023-10-29T20:00:00
# 4      CMSA-GAKH-01     uur  Kalverstraat t.h.v. 1  2023-02-01T18:00:00
# ...             ...     ...                    ...                  ...
# 12765  CMSA-GAKH-01    week  Kalverstraat t.h.v. 1  2023-12-04T00:00:00
# 12766  CMSA-GAKH-01    week  Kalverstraat t.h.v. 1  2023-12-18T00:00:00
# 12767  CMSA-GAKH-01    week  Kalverstraat t.h.v. 1  2023-01-02T00:00:00
# 12768  CMSA-GAKH-01    week  Kalverstraat t.h.v. 1  2023-05-01T00:00:00
# 12769  CMSA-GAKH-01    week  Kalverstraat t.h.v. 1  2023-03-06T00:00:00
#
#        aantalPassanten                gebied  \
# 0                 1150  Winkelgebied centrum
# 1                 2699  Winkelgebied centrum
# 2                   75  Winkelgebied centrum
# 3                  722  Winkelgebied centrum
# 4                 2188  Winkelgebied centrum
# ...                ...                   ...
# 12765           388658                  None
# 12766           431362                  None
# 12767           435843                  None
# 12768           422919                  None
# 12769           261281                  None
#
#                                                geometrie
# 0      {'type': 'Point', 'coordinates': [121281.37087...
# 1      {'type': 'Point', 'coordinates': [121281.37087...
# 2      {'type': 'Point', 'coordinates': [121281.37087...
# 3      {'type': 'Point', 'coordinates': [121281.37087...
# 4      {'type': 'Point', 'coordinates': [121281.37087...
# ...                                                  ...
# 12765                                               None
# 12766                                               None
# 12767                                               None
# 12768                                               None
# 12769                                               None
#
# [12770 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12770 entries, 0 to 12769
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _links           12770 non-null  object
#  1   id               12770 non-null  int64
#  2   sensor           12770 non-null  object
#  3   periode          12770 non-null  object
#  4   naamLocatie      12770 non-null  object
#  5   datumUur         12770 non-null  object
#  6   aantalPassanten  12770 non-null  int64
#  7   gebied           12353 non-null  object
#  8   geometrie        12353 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 898.0+ KB

# %%
df.describe()
# Out:
#                  id  aantalPassanten
# count  1.277000e+04     12770.000000
# mean   7.286785e+05      5038.958731
# std    4.189152e+05     28219.624290
# min    5.400000e+01        52.000000
# 25%    3.647688e+05       149.000000
# 50%    7.297055e+05       719.000000
# 75%    1.092756e+06      3455.750000
# max    1.454791e+06    567731.000000

# %%
df.to_csv('./data/kalverstraat2023.csv')
